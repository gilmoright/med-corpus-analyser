# %%
import os
import re
import json

# %%
original_file = "/s/ls4/users/zsaveliy/RE/RelationExtraction/data/otzovik/otzovik_for_rdrs_full.json"
parsed_file = "/s/ls4/users/grartem/SAG_MED/med-corpus-analyser/data/raw/ner_800k_jsonl/ner_800k.jsonl"

# %%
with open(original_file, "r") as f:
    original_data = json.load(f)

# %%
urls = []
with open(parsed_file, "r") as f:
    l_i = 0
    for line in f:
        data = json.loads(line)
        fixed = re.sub("[^а-яА-Я]", "", original_data[l_i]["raw"])
        fixed2 = re.sub("[^а-яА-Я]", "", data["text"])
        #assert len(fixed)>10
        if fixed2!=fixed:
            print(l_i)
        urls.append(original_data[l_i]["url"])
        l_i+=1
# Out:
# 75562
# 76153
# 78577
# 108133
# 165495
# 174629
# 220754
# 222851
# 248669
# 269681
# 323558
# 358851
# 361915
# 378370
# 383723
# 404810
# 420729
# 651758
# 652835
# 662380
# 695536
# 716785
# 722739

# %%
tags_set = set()
with open(parsed_file, "r") as f:
    l_i = 0
    for line in f:
        data = json.loads(line)
        for k,v in data["entities"].items():
            tags_set.add(v["tag"][0])
            assert len(v["tag"])==1
            assert "MedFrom" not in v["tag"][0]
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Input In [76], in <cell line: 2>()
#       7 tags_set.add(v["tag"][0])
#       8 assert len(v["tag"])==1
# ----> 9 assert "MedFrom" not in v["tag"][0]
#
# AssertionError:

# %%
data
# Out:
# {'text_id': 2,
#  'text': 'С сыном мы два раза лежали в больнице с бронхитом. На ряду с другими препаратами (сиропом от кашля, антибиотиком и пр.) для ингаляций нам прописывали . Был ещё в нашем опыте и . Ну и, конечно же, всем известная минеральная вода . Всё выше перечисленное хорошо помогало ребёнку в комплексе с основным лечением. Последний раз (этой весной) мы лежали в больнице с бронхитом уже с дочкой. Я не знаю по какой причине, но ей прописали для ингаляций "Небутамол", а не "Вентолин", хотя девочки по палате все говорили, что "Вентолин" для ребенка безопаснее и "мягче", если можно так выразиться о подобном препарате. Как и "Вентолин", он продается в виде таких вот пластиковых "ампул". Открывать их удобно. Расход у нас получился очень экономичным - одной такой "ампулы" нам хватало на один день. В день нужно было сделать две ингаляции, то есть содержимое делилось пополам на два раза. Так же, с определенным временным интервалом, мы делали ингаляции с "Боржоми". Эффект не заставил себя ждать. Уже на третий день ребенку стало легче, кашель почти прошел. Через три дня ингаляции с "Небутамолом" нам отменили, оставили только "Боржоми" два раза в день. Антибиотик тогда назначили "Цефтриаксон" - очень болезненный, но эффективный. Какой сироп пили, уже не помню, но точно на основе амброксола. Через 5 дней нас выписали домой! Считаю, что это достаточно быстро, ведь с сыном мы лежали в больнице в свое время 7 и 10 дней. *** Касательно противопоказаний, возрастных ограничений и прочего ничего сказать не могу, но болезнь у ребенка прошла быстро и без осложнений. Дочке в тот момент было примерно 1 год и 3 месяца, препарат назначался доктором. Стоимость препарата не дорогая, а расход для нас получился очень экономичным. Поэтому, с учетом эффективности, ничего плохого о "Небутамоле" сказать не могу. Единственное, что стоит учитывать для любого возраста - не назначать себе подобные препараты самостоятельно, а только по назначению лечащего врача. Ну и, конечно, для проведения процедуры Вам понадобится небулайзер, обычным паровым ингалятором такие процедуры не проводят. *** Отдельно хочется заметить удобство использования. В таких пластиковых "ампулках" удобно хранить остатки препарата, если нужно разделить его на две части, как в нашем случае. Препарат сам по себе не выливается, разве что надавить на флакон. К тому же, пластик исключает возможность пораниться, что тоже немаловажно. *** В общем, если нужно, то рекомендую данный препарат. А лучше, чтобы он не пригодился. Будьте здоровы!',
#  'entities': {'0': {'entity_id': 0,
#    'text': 'хорошо',
#    'tag': ['Disease:DisTypeBNE-Pos'],
#    'spans': [{'begin': 253, 'end': 259}]},
#   '1': {'entity_id': 1,
#    'text': 'помогало',
#    'tag': ['Disease:DisTypeBNE-Pos'],
#    'spans': [{'begin': 260, 'end': 268}]},
#   '2': {'entity_id': 2,
#    'text': 'Эффект не заставил себя ждать',
#    'tag': ['Disease:DisTypeBNE-Pos'],
#    'spans': [{'begin': 955, 'end': 984}]},
#   '3': {'entity_id': 3,
#    'text': 'на третий день',
#    'tag': ['Disease:DisTypeBNE-Pos'],
#    'spans': [{'begin': 990, 'end': 1004}]},
#   '4': {'entity_id': 4,
#    'text': 'ребенку стало легче , кашель почти прошел',
#    'tag': ['Disease:DisTypeBNE-Pos'],
#    'spans': [{'begin': 1005, 'end': 1045}]},
#   '5': {'entity_id': 5,
#    'text': 'эффективный 5',
#    'tag': ['Disease:DisTypeBNE-Pos'],
#    'spans': [{'begin': 1209, 'end': 1220}]},
#   '6': {'entity_id': 6,
#    'text': 'болезнь у ребенка прошла быстро и без осложнений',
#    'tag': ['Disease:DisTypeBNE-Pos'],
#    'spans': [{'begin': 1506, 'end': 1554}]},
#   '7': {'entity_id': 7,
#    'text': 'бронхитом',
#    'tag': ['Disease:DisTypeDiseasename'],
#    'spans': [{'begin': 40, 'end': 49}]},
#   '8': {'entity_id': 8,
#    'text': 'бронхитом',
#    'tag': ['Disease:DisTypeDiseasename'],
#    'spans': [{'begin': 361, 'end': 370}]},
#   '9': {'entity_id': 9,
#    'text': 'кашля',
#    'tag': ['Disease:DisTypeIndication'],
#    'spans': [{'begin': 93, 'end': 98}]},
#   '10': {'entity_id': 10,
#    'text': 'кашель',
#    'tag': ['Disease:DisTypeIndication'],
#    'spans': [{'begin': 1026, 'end': 1032}]},
#   '11': {'entity_id': 11,
#    'text': 'Боржоми',
#    'tag': ['Medication:MedFromDomestic'],
#    'spans': [{'begin': 945, 'end': 952}]},
#   '12': {'entity_id': 12,
#    'text': 'Боржоми',
#    'tag': ['Medication:MedFromDomestic'],
#    'spans': [{'begin': 1118, 'end': 1125}]},
#   '13': {'entity_id': 13,
#    'text': 'Небутамол',
#    'tag': ['Medication:MedFromForeign'],
#    'spans': [{'begin': 444, 'end': 453}]},
#   '14': {'entity_id': 14,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedFromForeign'],
#    'spans': [{'begin': 462, 'end': 470}]},
#   '15': {'entity_id': 15,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedFromForeign'],
#    'spans': [{'begin': 515, 'end': 523}]},
#   '16': {'entity_id': 16,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedFromForeign'],
#    'spans': [{'begin': 614, 'end': 622}]},
#   '17': {'entity_id': 17,
#    'text': 'Боржоми',
#    'tag': ['Medication:MedFromForeign'],
#    'spans': [{'begin': 945, 'end': 952}]},
#   '18': {'entity_id': 18,
#    'text': 'Небутамолом',
#    'tag': ['Medication:MedFromForeign'],
#    'spans': [{'begin': 1074, 'end': 1085}]},
#   '19': {'entity_id': 19,
#    'text': 'Цефтриаксон',
#    'tag': ['Medication:MedFromForeign'],
#    'spans': [{'begin': 1172, 'end': 1183}]},
#   '20': {'entity_id': 20,
#    'text': 'две',
#    'tag': ['Medication:MedTypeDosage'],
#    'spans': [{'begin': 813, 'end': 816}]},
#   '21': {'entity_id': 21,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedTypeDrugBrand'],
#    'spans': [{'begin': 462, 'end': 470}]},
#   '22': {'entity_id': 22,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedTypeDrugBrand'],
#    'spans': [{'begin': 515, 'end': 523}]},
#   '23': {'entity_id': 23,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedTypeDrugBrand'],
#    'spans': [{'begin': 614, 'end': 622}]},
#   '24': {'entity_id': 24,
#    'text': 'Цефтриаксон',
#    'tag': ['Medication:MedTypeDrugBrand'],
#    'spans': [{'begin': 1172, 'end': 1183}]},
#   '25': {'entity_id': 25,
#    'text': 'антибиотиком',
#    'tag': ['Medication:MedTypeDrugclass'],
#    'spans': [{'begin': 100, 'end': 112}]},
#   '26': {'entity_id': 26,
#    'text': 'Антибиотик',
#    'tag': ['Medication:MedTypeDrugclass'],
#    'spans': [{'begin': 1144, 'end': 1154}]},
#   '27': {'entity_id': 27,
#    'text': 'сиропом',
#    'tag': ['Medication:MedTypeDrugform'],
#    'spans': [{'begin': 82, 'end': 89}]},
#   '28': {'entity_id': 28,
#    'text': 'ампул',
#    'tag': ['Medication:MedTypeDrugform'],
#    'spans': [{'begin': 668, 'end': 673}]},
#   '29': {'entity_id': 29,
#    'text': 'ампулы',
#    'tag': ['Medication:MedTypeDrugform'],
#    'spans': [{'begin': 753, 'end': 759}]},
#   '30': {'entity_id': 30,
#    'text': 'сироп',
#    'tag': ['Medication:MedTypeDrugform'],
#    'spans': [{'begin': 1228, 'end': 1233}]},
#   '31': {'entity_id': 31,
#    'text': 'Небутамол',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 444, 'end': 453}]},
#   '32': {'entity_id': 32,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 462, 'end': 470}]},
#   '33': {'entity_id': 33,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 515, 'end': 523}]},
#   '34': {'entity_id': 34,
#    'text': 'Вентолин',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 614, 'end': 622}]},
#   '35': {'entity_id': 35,
#    'text': 'Боржоми',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 945, 'end': 952}]},
#   '36': {'entity_id': 36,
#    'text': 'Небутамолом',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 1074, 'end': 1085}]},
#   '37': {'entity_id': 37,
#    'text': 'Боржоми',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 1118, 'end': 1125}]},
#   '38': {'entity_id': 38,
#    'text': 'Цефтриаксон',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 1172, 'end': 1183}]},
#   '39': {'entity_id': 39,
#    'text': 'амброксола',
#    'tag': ['Medication:MedTypeDrugname'],
#    'spans': [{'begin': 1273, 'end': 1283}]},
#   '40': {'entity_id': 40,
#    'text': 'два раза в день',
#    'tag': ['Medication:MedTypeFrequency'],
#    'spans': [{'begin': 1127, 'end': 1142}]},
#   '41': {'entity_id': 41,
#    'text': 'для ингаляций',
#    'tag': ['Medication:MedTypeRoute'],
#    'spans': [{'begin': 120, 'end': 133}]},
#   '42': {'entity_id': 42,
#    'text': 'для ингаляций',
#    'tag': ['Medication:MedTypeRoute'],
#    'spans': [{'begin': 429, 'end': 442}]},
#   '43': {'entity_id': 43,
#    'text': 'В день сделать две ингаляции содержимое делилось пополам на два раза',
#    'tag': ['Medication:MedTypeRoute'],
#    'spans': [{'begin': 787, 'end': 793},
#     {'begin': 805, 'end': 826},
#     {'begin': 836, 'end': 875}]},
#   '44': {'entity_id': 44,
#    'text': 'делали ингаляции с',
#    'tag': ['Medication:MedTypeRoute'],
#    'spans': [{'begin': 925, 'end': 943}]},
#   '45': {'entity_id': 45,
#    'text': 'ингаляции',
#    'tag': ['Medication:MedTypeRoute'],
#    'spans': [{'begin': 1061, 'end': 1070}]},
#   '46': {'entity_id': 46,
#    'text': 'пили',
#    'tag': ['Medication:MedTypeRoute'],
#    'spans': [{'begin': 1234, 'end': 1238}]},
#   '47': {'entity_id': 47,
#    'text': 'прописывали',
#    'tag': ['Medication:MedTypeSourceInfodrug'],
#    'spans': [{'begin': 138, 'end': 149}]},
#   '48': {'entity_id': 48,
#    'text': 'прописали',
#    'tag': ['Medication:MedTypeSourceInfodrug'],
#    'spans': [{'begin': 419, 'end': 428}]},
#   '49': {'entity_id': 49,
#    'text': 'назначили',
#    'tag': ['Medication:MedTypeSourceInfodrug'],
#    'spans': [{'begin': 1161, 'end': 1170}]},
#   '50': {'entity_id': 50,
#    'text': 'назначался доктором',
#    'tag': ['Medication:MedTypeSourceInfodrug'],
#    'spans': [{'begin': 1616, 'end': 1635}]}}}

# %%
tags_set
# Out:
# {'ADR',
#  'Disease:DisTypeADE-Neg',
#  'Disease:DisTypeBNE-Pos',
#  'Disease:DisTypeDiseasename',
#  'Disease:DisTypeIndication',
#  'Disease:DisTypeNegatedADE',
#  'Disease:DisTypeWorse',
#  'Medication:MedFromDomestic',
#  'Medication:MedFromForeign',
#  'Medication:MedMakerDomestic',
#  'Medication:MedMakerForeign',
#  'Medication:MedTypeDosage',
#  'Medication:MedTypeDrugBrand',
#  'Medication:MedTypeDrugclass',
#  'Medication:MedTypeDrugform',
#  'Medication:MedTypeDrugname',
#  'Medication:MedTypeDuration',
#  'Medication:MedTypeFrequency',
#  'Medication:MedTypeMedMaker',
#  'Medication:MedTypeRoute',
